# %%
import pandas as pd

import numpy as np

import matplotlib as plt

df = pd.read_csv("/home/vanemtzl/computacional/Datos de todos los meses/Actividad 3/Datos12Z.csv")

# %%
df.head(20)
# Out:
#            Fecha  CAPE  Agua Precipitable
# 0    01 Jan 2016  0.00               7.46
# 1    02 Jan 2016  0.00               5.85
# 2    03 Jan 2016  0.00               5.16
# 3    04 Jan 2016  0.00               4.89
# 4    05 Jan 2016  0.00              10.49
# 5    06 Jan 2016  0.00              11.57
# 6    07 Jan 2016  0.00               6.75
# 7    08 Jan 2016  0.84               6.45
# 8    09 Jan 2016  0.00               6.28
# 9    10 Jan 2016  0.00               4.39
# 10   11 Jan 2016  0.00               3.00
# 11   12 Jan 2016  0.00               2.73
# 12   13 Jan 2016  0.00               2.52
# 13   14 Jan 2016  0.00               3.14
# 14   15 Jan 2016  0.00               5.04
# 15   16 Jan 2016  0.00               5.11
# 16   17 Jan 2016  0.00               5.80
# 17   18 Jan 2016  0.00               5.61
# 18   19 Jan 2016  0.00               6.96
# 19   20 Jan 2016  0.00               8.98

# %%
df.describe()
# Out:
#              CAPE  Agua Precipitable
# count  364.000000         364.000000
# mean    23.346346          12.339231
# std     86.905569           7.687457
# min      0.000000           1.530000
# 25%      0.000000           5.997500
# 50%      0.000000          10.225000
# 75%      0.000000          17.877500
# max    801.010000          34.110000

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
#  Fecha               0
# CAPE                 0
# Agua Precipitable    0
# dtype: int64

# %%
df.columns
# Out:
# Index([' Fecha', 'CAPE', 'Agua Precipitable'], dtype='object')

# %%
matplotlib inline

# %%
df.hist(u'CAPE',bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc15881f7f0>]], dtype=object)

# %%
df.boxplot(column=u'CAPE',return_type='axes')

# %%
df['month']=pd.DatetimeIndex(df[u' Fecha']).month

# %%
df.boxplot(column=u'CAPE', by=u'month')

# %%
df.hist(u'Agua Precipitable',bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc15592eb38>]], dtype=object)

# %%
df.boxplot(column=u'Agua Precipitable',return_type='axes')

# %%
df.boxplot(column=u'Agua Precipitable', by=u'month')
