# %%
import pandas as pd

import numpy as np

import matplotlib as plt

df = pd.read_csv("/home/vanemtzl/computacional/Datos de todos los meses/Actividad 3/Datos00Z.csv")

# %%
df.head(20)
# Out:
#            Fecha   CAPE  Agua Precipitable  month
# 0    01 Jan 2016   0.00               3.18      1
# 1    02 Jan 2016   0.00               6.78      1
# 2    03 Jan 2016   0.00               5.02      1
# 3    04 Jan 2016   0.00               5.37      1
# 4    05 Jan 2016   0.00               9.55      1
# 5    06 Jan 2016   0.00               9.31      1
# 6    07 Jan 2016  84.20               7.32      1
# 7    08 Jan 2016   7.81               8.46      1
# 8    09 Jan 2016   0.00               7.09      1
# 9    10 Jan 2016   0.00               4.94      1
# 10   11 Jan 2016   0.00               5.81      1
# 11   12 Jan 2016   0.00               3.96      1
# 12   13 Jan 2016   0.00               2.76      1
# 13   14 Jan 2016   0.00               2.69      1
# 14   15 Jan 2016   0.00               4.00      1
# 15   16 Jan 2016   0.00               8.11      1
# 16   17 Jan 2016   0.00               6.17      1
# 17   18 Jan 2016   0.00               5.07      1
# ...

# %%
df.describe()
# Out:
#               CAPE  Agua Precipitable
# count   363.000000         363.000000
# mean     90.845510          11.589311
# std     185.025789           7.146926
# min       0.000000           1.800000
# 25%       0.000000           5.965000
# 50%       0.000000           9.210000
# 75%      76.535000          16.490000
# max    1092.790000          32.120000

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
#  Fecha               0
# CAPE                 0
# Agua Precipitable    0
# dtype: int64

# %%
df.columns
# Out:
# Index([' Fecha', 'CAPE', 'Agua Precipitable'], dtype='object')

# %%
matplotlib inline

# %%
df.hist(u'CAPE',bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4f6f474978>]], dtype=object)

# %%
df.boxplot(column=u'CAPE',return_type='axes')

# %%
df['month']=pd.DatetimeIndex(df[u' Fecha']).month

# %%
df.boxplot(column=u'CAPE', by=u'month')

# %%
df.hist(u'Agua Precipitable',bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4f69c5c160>]], dtype=object)

# %%
df.boxplot(column=u'Agua Precipitable',return_type='axes')

# %%
df.boxplot(column=u'Agua Precipitable', by=u'month')
