# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mplt
import pylab as plt
from matplotlib import rc
from pylab import figure, show, legend, xlabel, ylabel
df=pd.read_csv("/home/vanemtzl/Actividad 5/AtlanticEnero.csv", parse_dates=['Date Time'])

# %%
df.columns=['Date','Water Level','Sigma','O','F','R','L', 'Quality']

# %%
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Date           0
# Water Level    0
# Sigma          0
# O              0
# F              0
# R              0
# L              0
# Quality        0
# dtype: int64

# %%
df.head()
# Out:
#                  Date  Water Level  Sigma  O  F  R  L Quality
# 0 2017-01-01 00:00:00        0.784  0.184  0  0  0  0       v
# 1 2017-01-01 00:06:00        0.825  0.206  0  0  0  0       v
# 2 2017-01-01 00:12:00        0.868  0.184  0  0  0  0       v
# 3 2017-01-01 00:18:00        0.853  0.193  0  0  0  0       v
# 4 2017-01-01 00:24:00        0.846  0.153  0  0  0  0       v

# %%
x=df["Date"]
y=df["Water Level"]

plt.title("Mareas en Atlantic City, NJ, Enero 2017")
plt.ylabel('Nivel del agua (m)')
plt.xlabel('Fecha')
plt.grid(True)
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)

mplt.plot(x,y, color='aqua')
plt.show()
