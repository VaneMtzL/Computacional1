# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mplt
import pylab as plt
from matplotlib import rc
from pylab import figure, show, legend, xlabel, ylabel
df=pd.read_csv("/home/vanemtzl/Actividad 5/CaboAbril.csv")

# %%
df.columns
# Out:
# Index(['Año', 'Mes', 'Día', 'Hora(utc)', 'Altura(mm)'], dtype='object')

# %%
from datetime import datetime
df['date']= df.apply(lambda x:datetime.strptime("{0} {1} {2} {3}".format(x[u'Año'],x[u'Mes'], x[u'Día'], x[u'Hora(utc)']), "%Y %m %d %H"),axis=1)

# %%
df.head(10)
# Out:
#     Año  Mes  Día  Hora(utc)  Altura(mm)                date
# 0  2016    4    1          0         524 2016-04-01 00:00:00
# 1  2016    4    1          1         546 2016-04-01 01:00:00
# 2  2016    4    1          2         568 2016-04-01 02:00:00
# 3  2016    4    1          3         590 2016-04-01 03:00:00
# 4  2016    4    1          4         607 2016-04-01 04:00:00
# 5  2016    4    1          5         623 2016-04-01 05:00:00
# 6  2016    4    1          6         643 2016-04-01 06:00:00
# 7  2016    4    1          7         669 2016-04-01 07:00:00
# 8  2016    4    1          8         694 2016-04-01 08:00:00
# 9  2016    4    1          9         710 2016-04-01 09:00:00

# %%
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Año           0
# Mes           0
# Día           0
# Hora(utc)     0
# Altura(mm)    0
# date          0
# dtype: int64

# %%
x=df["date"]
y=df["Altura(mm)"]

plt.title("Mareas en Cabo San Lucas, BCS, Abril 2016")
plt.ylabel('Nivel del agua (mm)')
plt.xlabel('Fecha')
plt.grid(True)
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)

mplt.plot(x,y)
plt.show()
