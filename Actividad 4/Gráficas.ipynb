# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mplt
import pylab as plt
from matplotlib import rc
from pylab import figure, show, legend, xlabel, ylabel
df = pd.read_csv("/home/vanemtzl/Actividad 4/15feb17.csv")

# %%
df.head(15)
# Out:
#       PRES  HGHT  TEMP  DWPT RELH  MIXR DRCT SKNT   THTA   THTE   THTV
# 0   1000.0   212
# 1    925.0   863
# 2    850.0  1560
# 3    844.0  1619   1.6  -1.1   82  4.20   25    3  288.4  300.7  289.1
# 4    840.0  1657   2.2  -3.8   65  3.45  359    3  289.4  299.6  290.0
# 5    825.0  1803   2.4  -4.6   60  3.31  263    3  291.1  301.0  291.7
# 6    822.3  1829   2.2  -4.6   61  3.32  245    3  291.1  301.1  291.7
# 7    803.0  2020   0.4  -4.6   69  3.40  339    2  291.2  301.4  291.9
# 8    794.0  2111   0.8  -5.2   64  3.28   24    1  292.6  302.5  293.2
# 9    791.7  2134   0.6  -5.3   65  3.27   35    1  292.6  302.5  293.2
# 10   762.1  2438  -2.1  -6.7   71  3.05  230    1  292.9  302.2  293.5
# 11   760.0  2460  -2.3  -6.8   71  3.04  222    1  292.9  302.1  293.5
# 12   733.3  2743  -4.7  -6.4   88  3.24  120    2  293.4  303.2  293.9
# 13   733.0  2746  -4.7  -6.4   88  3.25  119    2  293.4  303.2  293.9
# ...

# %%
df.columns= ['Presión','Altura','Temperatura','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV']

# %%
x=df[u'Presión']
y=df[u'Altura']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Presión (hPa)')
plt.ylabel('Altura (m)')

# %%
plt.show()

# %%
df = pd.read_csv("/home/vanemtzl/Actividad 4/15feb17temp.csv")

# %%
df.columns= ['Presión','Altura','Temperatura','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV']

# %%
x=df[u'Temperatura']
y=df[u'Altura']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Temperatura (°C)')
plt.ylabel('Altura (m)')

# %%
plt.show()

# %%
x=df[u'DWPT']
y=df[u'Altura']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Temperatura de rocío (°C)')
plt.ylabel('Altura (m)')

# %%
plt.show()

# %%
x=df[u'Temperatura']
y=df[u'Altura']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Temperatura (°C)')
plt.ylabel('Altura (m)')

# %%
x=df[u'DWPT']
y=df[u'Altura']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Temperaturas (°C)')
plt.ylabel('Altura (m)')

# %%
plt.show()

# %%
import os.path

# %%
import tephi as tph

# %%
dew_point = pd.read_csv("/home/vanemtzl/Actividad 4/dwpt.csv", names=["Presión", "DWPT"])
dry_bulb = pd.read_csv("/home/vanemtzl/Actividad 4/temp.csv", names=["Presión", "Temperatura"])

# %%
tpg = tph.Tephigram()
tpg.plot(dew_point)
tpg.plot(dry_bulb)
plt.show()
